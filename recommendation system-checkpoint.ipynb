# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('movie_recommendation_system.csv')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv('movie_id.csv')
movie_titles.head()
# Out:
#    item_id                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
df = pd.merge(df,movie_titles,on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp                       title
# 0        0       50       5  881250949  Usual Suspects, The (1995)
# 1      290       50       5  880473582  Usual Suspects, The (1995)
# 2       79       50       4  891271545  Usual Suspects, The (1995)
# 3        2       50       5  888552084  Usual Suspects, The (1995)
# 4        8       50       5  879362124  Usual Suspects, The (1995)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Thin Blue Line, The (1988)                                                   5.0
# Boy Called Hate, A (1995)                                                    5.0
# Grosse Pointe Blank (1997)                                                   5.0
# Salut cousin! (1996)                                                         5.0
# Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)    5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Usual Suspects, The (1995)                        584
# Kid in King Arthur's Court, A (1995)              509
# City Hall (1996)                                  508
# Mighty Morphin Power Rangers: The Movie (1995)    507
# Perez Family, The (1995)                          485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                                 rating
# title
# 'Til There Was You (1997)     2.548387
# 1-900 (06) (1994)             3.384615
# 101 Dalmatians (1996)         4.200000
# 12 Angry Men (1957)           4.047619
# 187 (One Eight Seven) (1997)  1.666667

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
# Out:
#                                 rating  num of ratings
# title
# 'Til There Was You (1997)     2.548387              31
# 1-900 (06) (1994)             3.384615              13
# 101 Dalmatians (1996)         4.200000               5
# 12 Angry Men (1957)           4.047619              21
# 187 (One Eight Seven) (1997)  1.666667               3

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (06) (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN                NaN                    NaN
# 1                              NaN                NaN                    NaN
# 2                              NaN                NaN                    NaN
# 3                              NaN                NaN                    NaN
# 4                              NaN                NaN                    NaN
#
# title    12 Angry Men (1957)  187 (One Eight Seven) (1997)  \
# user_id
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
# title    2 Days in the Valley (1996)  \
# user_id
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# title    2 ou 3 choses que je sais d'elle (2 or 3 Things I Know About Her) (1967)  \
# user_id
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        NaN                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
#
# title    301, 302 (301/302) (1995)  ...  Wyatt Earp (1994)  \
# user_id                             ...
# 0                              NaN  ...                NaN
# 1                              NaN  ...                NaN
# 2                              NaN  ...                NaN
# 3                              NaN  ...                NaN
# 4                              NaN  ...                NaN
#
# title    Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
# title    Yes, Madam (a.k.a. Police Assassins) (a.k.a. In the Line of Duty 2) (Huang gu shi jie) (1985)  \
# user_id
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
# title    Young Frankenstein (1974)  Young Guns (1988)  Young Guns II (1990)  \
# user_id
# 0                              NaN                NaN                   NaN
# 1                              NaN                NaN                   NaN
# 2                              NaN                NaN                   NaN
# 3                              NaN                NaN                   NaN
# 4                              NaN                NaN                   NaN
#
# title    Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                                          NaN
# 1                                          3.0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
# title    Zero Kelvin (Kjærlighetens kjøtere) (1995)  Zeus and Roxanne (1997)
# user_id
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
#
# [5 rows x 1621 columns]

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                                   rating  num of ratings
# title
# Usual Suspects, The (1995)                      4.359589             584
# Kid in King Arthur's Court, A (1995)            3.803536             509
# City Hall (1996)                                4.155512             508
# Mighty Morphin Power Rangers: The Movie (1995)  4.007890             507
# Perez Family, The (1995)                        3.156701             485
# Nemesis 2: Nebula (1995)                        3.656965             481
# Natural Born Killers (1994)                     3.441423             478
# Toy Story (1995)                                3.878319             452
# Quiz Show (1994)                                3.631090             431
# Boys of St. Vincent, The (1992)                 3.438228             429

# %%
starwars_user_ratings = moviemat['Star Wars: Episode IV - A New Hope (1977)']
liarliar_user_ratings = moviemat['Liar Liar (1997)']
starwars_user_ratings.head()
# Out:
# user_id
# 0    NaN
# 1    1.0
# 2    NaN
# 3    4.0
# 4    4.0
# Name: Star Wars: Episode IV - A New Hope (1977), dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\numpy\lib\function_base.py:2821: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\saiku\anaconda3\lib\site-packages\numpy\lib\function_base.py:2680: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\saiku\anaconda3\lib\site-packages\numpy\lib\function_base.py:2821: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\saiku\anaconda3\lib\site-packages\numpy\lib\function_base.py:2680: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                                      Correlation
# title
# 'Til There Was You (1997)               0.423442
# 1-900 (06) (1994)                      -1.000000
# 101 Dalmatians (1996)                   1.000000
# 12 Angry Men (1957)                     0.000000
# 20,000 Leagues Under the Sea (1954)     0.801784

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                       Correlation
# title
# Meet Wally Sparks (1997)                      1.0
# Adventures of Pinocchio, The (1996)           1.0
# Boot, Das (Boat, The) (1981)                  1.0
# Macao (1952)                                  1.0
# Mars Attacks! (1996)                          1.0
# Ben-Hur (1959)                                1.0
# Amityville Horror, The (1979)                 1.0
# Amityville II: The Possession (1982)          1.0
# Batman Returns (1992)                         1.0
# People vs. Larry Flynt, The (1996)            1.0

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                                      Correlation  num of ratings
# title
# 'Til There Was You (1997)               0.423442              31
# 1-900 (06) (1994)                      -1.000000              13
# 101 Dalmatians (1996)                   1.000000               5
# 12 Angry Men (1957)                     0.000000              21
# 20,000 Leagues Under the Sea (1954)     0.801784              31

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                            Correlation  num of ratings
# title
# Star Wars: Episode IV - A New Hope (1977)     1.000000             127
# Cure, The (1995)                              0.600235             111
# Trial by Jury (1994)                          0.595143             102
# Force of Evil (1948)                          0.545921             119
# Basketball Diaries, The (1995)                0.522642             185

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Young Poisoner's Handbook, The (1995)                       1.0
# Run of the Country, The (1995)                              1.0
# Far From Home: The Adventures of Yellow Dog (1995)          1.0
# Jury Duty (1995)                                            1.0
# Mad Love (1995)                                             1.0
#
#                                                     num of ratings
# title
# Young Poisoner's Handbook, The (1995)                          378
# Run of the Country, The (1995)                                 107
# Far From Home: The Adventures of Yellow Dog (1995)             256
# Jury Duty (1995)                                               420
# Mad Love (1995)                                                221
